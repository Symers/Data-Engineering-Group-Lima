# %%
import pandas as pd

datafile1 = "financial_compliance_source.csv"
datafile2 = "financial_compliance_target.csv"
targetTable = pd.read_csv(datafile2)
inputTable = pd.read_csv(datafile1)
df_meta
# Out:
#    year      firm_name  total_audit_engagement  high_risk_cases_count  \
# 0  2024       Deloitte                    1581                    247
# 1  2025       Deloitte                     760                    406
# 2  2023            PwC                    2238                    101
# 3  2024  Ernst & Young                    1760                    415
# 4  2024            PwC                    4103                    423
#
#    compliance_violations_count  fraud_cases_count industry_affected  \
# 0                          181                 72            Retail
# 1                           65                 69           Finance
# 2                          184                 79            Retail
# 3                          183                 11        Healthcare
# 4                          179                 30        Healthcare
#
#    revenue_impact_millions  ai_used  employee_workload_percent  \
# 0                   221.42        0                         56
# 1                   140.29        1                         40
# 2                   216.84        1                         65
# 3                   291.00        1                         53
# 4                   225.42        1                         41
#
#    audit_impact_score  client_satisfaction_score  overall_score
# 0                 5.6                        7.9           6.75
# 1                 5.1                        7.5           6.30
# 2                 7.0                        7.1           7.05
# 3                 8.2                        8.4           8.30
# 4                 6.7                        5.0           5.85
